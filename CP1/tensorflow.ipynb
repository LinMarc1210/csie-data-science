# %% [markdown]
# # Read All Dataset CSV

# %%
import os
import csv
import re
import pandas as pd
import numpy as np

# %%
dataset_names=[]
X_trains=[]
y_trains=[]
X_tests=[]

# 收集所有資料夾名稱，按照數字順序排序資料夾名稱
for folder_name in os.listdir("./Competition_data"):
    dataset_names.append(folder_name)
dataset_names = sorted(dataset_names, key=lambda x: int(re.search(r'\d+', x).group()))

for folder_name in dataset_names:
    # print(folder_name)
    X_trains.append(pd.read_csv(f"./Competition_data/{folder_name}/X_train.csv",header=0))
    y_trains.append(pd.read_csv(f"./Competition_data/{folder_name}/y_train.csv",header=0))
    X_tests.append(pd.read_csv(f"./Competition_data/{folder_name}/X_test.csv",header=0))
    
    
    
# print(len(dataset_names))
# print(len(X_trains))  # 49, 代表有 49 個 dataFrame (每個資料集各一個)
# print(len(y_trains))
# print(len(X_tests))
# print(X_trains[0].dtypes)
# print(y_trains[0].dtypes)

# %%
# print(X_trains[42])

# %% [markdown]
# ## Data Preprocessing & Feature Engineering

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelBinarizer

# 對每組資料進行處理
for i in range(len(dataset_names)):
    # 將連續型資料和數值型資料標準化
    numerical_df = X_trains[i].select_dtypes(include=['float'])   # 數值型特徵
    categorical_df = X_trains[i].select_dtypes(include=['int'])   # 類別型特徵（可能為類別特徵）
    if len(numerical_df.columns) + len(categorical_df.columns) != len(X_trains[i].columns):
        print('Splitting error')
    # numerical_df --> normalization
    scaler = StandardScaler()
    scaler.fit(numerical_df)
    numerical_s = scaler.transform(numerical_df)
    numerical_df = pd.DataFrame(numerical_s, columns=numerical_df.columns)
    X_trains[i] = pd.concat([numerical_df, categorical_df], axis=1)
    
    
    numerical_df = X_tests[i].select_dtypes(include=['float'])   # 數值型特徵
    categorical_df = X_tests[i].select_dtypes(include=['int'])   # 類別型特徵（可能為類別特徵）
    # 直接照前面用過的 scaler 來分
    numerical_s = scaler.transform(numerical_df)
    numerical_df = pd.DataFrame(numerical_s, columns=numerical_df.columns)
    X_tests[i] = pd.concat([numerical_df, categorical_df], axis=1)

for i in range(len(dataset_names)):
    y_trains[i].iloc[:, 0] = pd.to_numeric(y_trains[i].iloc[:, 0])

# %%
# from sklearn.preprocessing import MinMaxScaler, LabelBinarizer

# def preprocess_data(df, scaler=None, label_binarizers=None, columns=None):
#     # 將連續型資料和數值型資料標準化
#     numerical_df = df.select_dtypes(include=['float'])   # 數值型特徵
#     categorical_df = df.select_dtypes(include=['int'])   # 類別型特徵（可能為類別特徵）

#     # numerical_df --> normalization
#     if scaler is None:
#         scaler = MinMaxScaler()
#         scaler.fit(numerical_df)
#     numerical_s = scaler.transform(numerical_df)
#     numerical_df = pd.DataFrame(numerical_s, columns=numerical_df.columns)

#     # categorial_df --> label binarizer encoding
#     if label_binarizers is None:
#         label_binarizers = {}

#     encoded_cols = []
#     for col in categorical_df.columns:
#         unique_values = categorical_df[col].nunique()

#         if col not in label_binarizers:
#             c_scaler = LabelBinarizer()
#             c_scaler.fit(categorical_df[col])
#             label_binarizers[col] = c_scaler
#         encoded_df = label_binarizers[col].transform(categorical_df[col])  # 轉成 ndarray

#         # 如果是多類別，轉換成 DataFrame，並加上欄位名稱
#         if encoded_df.shape[1] > 1:
#             encoded_df = pd.DataFrame(encoded_df, columns=[f"{col}_{cls}" for cls in label_binarizers[col].classes_])
#         else:
#             encoded_df = pd.Series(encoded_df.flatten(), name=categorical_df[col].name)
#         encoded_cols.append(encoded_df)

#     encoded_df = pd.concat([categorical_df.drop(columns=categorical_df.columns)] + encoded_cols, axis=1)

#     # 如果是測試資料，補齊缺少的欄位並重新排序
#     if columns is not None:
#         missing_cols = set(columns) - set(encoded_df.columns)
#         for col in missing_cols:
#             encoded_df[col] = 0  # 缺失的欄位補 0
#         encoded_df = encoded_df[columns]  # 重新排序以匹配訓練資料的欄位順序

#     # 合併數值型和類別型資料框
#     processed_df = pd.concat([numerical_df, encoded_df], axis=1)
#     processed_df = processed_df[columns] if columns is not None else processed_df

#     return processed_df, scaler, label_binarizers

# # 對每組資料進行處理
# for i in range(len(dataset_names)):
#     X_trains[i], n_scaler, label_binarizers = preprocess_data(X_trains[i])
#     X_tests[i], _, _ = preprocess_data(X_tests[i], scaler=n_scaler, label_binarizers=label_binarizers, columns=X_trains[i].columns)

# %%
# for i in range(len(dataset_names)):
#     missing_cols = set(X_trains[i].columns) - set(X_tests[i].columns)
#     print(missing_cols)

# %% [markdown]
# ## train test split & build Model
# You can select an appropriate model and perform corresponding hyperparameter tuning.

# %%
# !pip install tensorflow

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
# from sklearn.metrics import accuracy_score, f1_score, precision_score
from sklearn.metrics import roc_auc_score
# from xgboost import XGBClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow import keras
from tensorflow.keras.regularizers import l2

# %%
# models=[]
# avg_auc = 0
# avg_train = 0
# for i in range(len(dataset_names)):
#     # 這邊做一下 stratify
#     tmp_X_train, tmp_X_test, tmp_y_train, tmp_y_test = train_test_split(
#         X_trains[i], y_trains[i], test_size=0.2, random_state=42, stratify=y_trains[i]
#     )
#     # Random Forest (適合這次的小資料集)
#     model = RandomForestClassifier(
#         n_estimators=400, n_jobs=1, random_state=1, max_depth=7,  
#     )

#     # # Neural Net
#     # model = MLPClassifier(
#     #     hidden_layer_sizes=(128,64),
#     #     activation="relu",
#     #     random_state=1,
#     #     alpha=0.01
#     # )
    
#     # # XGBoost (好像比較容易過擬合，適合大資料集) 
#     # model = XGBClassifier(
#     #     n_estimators=200, learning_rate=0.1, gamma=0.8,
#     # )
    
#     model.fit(tmp_X_train, tmp_y_train.squeeze())
    
#     tmp_y_prob = model.predict_proba(tmp_X_test)[:, 1]
#     auc = roc_auc_score(tmp_y_test, tmp_y_prob)
#     # print(f'auc of dataset {i:2}: \t{auc}')
#     avg_auc += auc
#     models.append(model)
    
# print(avg_auc / len(dataset_names))

# %%
models=[]
avg_auc = 0
avg_train = 0
for i in range(len(dataset_names)):
    # 這邊做一下 stratify
    tmp_X_train, tmp_X_test, tmp_y_train, tmp_y_test = train_test_split(
        X_trains[i], y_trains[i], test_size=0.2, random_state=42, stratify=y_trains[i]
    )
    

    
#     # Random Forest (適合這次的小資料集)
#     model = RandomForestClassifier(
#         n_estimators=400, n_jobs=1, random_state=1, max_depth=7,  
#     )

#     #tensorflow(1)(0.820698)
#     model = Sequential()
#     model.add(Dense(units=16, activation='relu', input_shape=(X_trains[i].shape[1],)))
#     model.add(Dense(1, activation='sigmoid'))
#     adam = keras.optimizers.Adam(learning_rate=0.001)
#     model.compile(loss='binary_crossentropy', optimizer=adam, metrics=["accuracy"])
    
#     model.fit(tmp_X_train, tmp_y_train.squeeze(), epochs=100)
    
    #tensorflow(2)(0.842297)
    model = Sequential()
    model.add(Dense(units=32, activation='relu', input_shape=(X_trains[i].shape[1],), kernel_regularizer=l2(0.01)))
    model.add(Dense(1, activation='sigmoid'))
    adam = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=["accuracy"])
    
    model.fit(tmp_X_train, tmp_y_train.squeeze(), epochs=100)
    

    # # Neural Net
    # model = MLPClassifier(
    #     hidden_layer_sizes=(128,64),
    #     activation="relu",
    #     random_state=1,
    #     alpha=0.01
    # )
    
    # # XGBoost (好像比較容易過擬合，適合大資料集) 
    # model = XGBClassifier(
    #     n_estimators=200, learning_rate=0.1, gamma=0.8,
    # )
    
#     model.fit(tmp_X_train, tmp_y_train.squeeze())
    
    tmp_y_prob = model.predict(tmp_X_test).ravel()
    auc = roc_auc_score(tmp_y_test, tmp_y_prob)
    # print(f'auc of dataset {i:2}: \t{auc}')
    avg_auc += auc
    models.append(model)
    
print(avg_auc / len(dataset_names))
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8569 - accuracy: 0.4873
# Epoch 2/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8135 - accuracy: 0.5296
# Epoch 3/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7798 - accuracy: 0.5746
# Epoch 4/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7523 - accuracy: 0.6310
# Epoch 5/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7316 - accuracy: 0.6535
# Epoch 6/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7137 - accuracy: 0.6789
# Epoch 7/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6985 - accuracy: 0.7014
# Epoch 8/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6840 - accuracy: 0.7239
# Epoch 9/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6716 - accuracy: 0.7296
# Epoch 10/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6608 - accuracy: 0.7296
# Epoch 11/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6510 - accuracy: 0.7324
# Epoch 12/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6419 - accuracy: 0.7324
# Epoch 13/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6332 - accuracy: 0.7324
# Epoch 14/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6261 - accuracy: 0.7324
# Epoch 15/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6191 - accuracy: 0.7324
# Epoch 16/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6125 - accuracy: 0.7380
# Epoch 17/100
# 12/12 [==============================] - 0s 981us/step - loss: 0.6063 - accuracy: 0.7408
# Epoch 18/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6009 - accuracy: 0.7437
# Epoch 19/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5955 - accuracy: 0.7465
# Epoch 20/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5903 - accuracy: 0.7521
# Epoch 21/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5857 - accuracy: 0.7606
# Epoch 22/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5817 - accuracy: 0.7634
# Epoch 23/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5777 - accuracy: 0.7606
# Epoch 24/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5739 - accuracy: 0.7634
# Epoch 25/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5707 - accuracy: 0.7662
# Epoch 26/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5670 - accuracy: 0.7634
# Epoch 27/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5632 - accuracy: 0.7690
# Epoch 28/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5597 - accuracy: 0.7746
# Epoch 29/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5566 - accuracy: 0.7775
# Epoch 30/100
# 12/12 [==============================] - 0s 927us/step - loss: 0.5538 - accuracy: 0.7746
# Epoch 31/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5516 - accuracy: 0.7746
# Epoch 32/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5491 - accuracy: 0.7746
# Epoch 33/100
# 12/12 [==============================] - 0s 914us/step - loss: 0.5467 - accuracy: 0.7746
# Epoch 34/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5443 - accuracy: 0.7746
# Epoch 35/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5419 - accuracy: 0.7746
# Epoch 36/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5399 - accuracy: 0.7718
# Epoch 37/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5380 - accuracy: 0.7718
# Epoch 38/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7746
# Epoch 39/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5341 - accuracy: 0.7718
# Epoch 40/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.7746
# Epoch 41/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5304 - accuracy: 0.7718
# Epoch 42/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5290 - accuracy: 0.7690
# Epoch 43/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5278 - accuracy: 0.7690
# Epoch 44/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5262 - accuracy: 0.7690
# Epoch 45/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5248 - accuracy: 0.7746
# Epoch 46/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5230 - accuracy: 0.7746
# Epoch 47/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.7718
# Epoch 48/100
# 12/12 [==============================] - 0s 949us/step - loss: 0.5206 - accuracy: 0.7718
# Epoch 49/100
# 12/12 [==============================] - 0s 981us/step - loss: 0.5190 - accuracy: 0.7746
# Epoch 50/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5180 - accuracy: 0.7775
# Epoch 51/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5172 - accuracy: 0.7803
# Epoch 52/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5161 - accuracy: 0.7831
# Epoch 53/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5153 - accuracy: 0.7803
# Epoch 54/100
# 12/12 [==============================] - 0s 997us/step - loss: 0.5139 - accuracy: 0.7775
# Epoch 55/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5128 - accuracy: 0.7803
# Epoch 56/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5117 - accuracy: 0.7746
# Epoch 57/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5107 - accuracy: 0.7775
# Epoch 58/100
# 12/12 [==============================] - 0s 965us/step - loss: 0.5096 - accuracy: 0.7831
# Epoch 59/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5090 - accuracy: 0.7775
# Epoch 60/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5082 - accuracy: 0.7803
# Epoch 61/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5071 - accuracy: 0.7803
# Epoch 62/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5057 - accuracy: 0.7775
# Epoch 63/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5047 - accuracy: 0.7718
# Epoch 64/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5043 - accuracy: 0.7690
# Epoch 65/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5028 - accuracy: 0.7662
# Epoch 66/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5020 - accuracy: 0.7690
# Epoch 67/100
# 12/12 [==============================] - 0s 992us/step - loss: 0.5016 - accuracy: 0.7690
# Epoch 68/100
# 12/12 [==============================] - 0s 991us/step - loss: 0.5012 - accuracy: 0.7690
# Epoch 69/100
# 12/12 [==============================] - 0s 893us/step - loss: 0.5005 - accuracy: 0.7690
# Epoch 70/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5000 - accuracy: 0.7718
# Epoch 71/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4991 - accuracy: 0.7746
# Epoch 72/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4985 - accuracy: 0.7718
# Epoch 73/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4977 - accuracy: 0.7746
# Epoch 74/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4971 - accuracy: 0.7718
# Epoch 75/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4964 - accuracy: 0.7718
# Epoch 76/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4961 - accuracy: 0.7746
# Epoch 77/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4955 - accuracy: 0.7775
# Epoch 78/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4952 - accuracy: 0.7746
# Epoch 79/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4945 - accuracy: 0.7746
# Epoch 80/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4939 - accuracy: 0.7746
# Epoch 81/100
# 12/12 [==============================] - 0s 984us/step - loss: 0.4933 - accuracy: 0.7746
# Epoch 82/100
# 12/12 [==============================] - 0s 977us/step - loss: 0.4925 - accuracy: 0.7690
# Epoch 83/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4919 - accuracy: 0.7662
# Epoch 84/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4912 - accuracy: 0.7634
# Epoch 85/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4906 - accuracy: 0.7718
# Epoch 86/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4898 - accuracy: 0.7690
# Epoch 87/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4903 - accuracy: 0.7690
# Epoch 88/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4894 - accuracy: 0.7634
# Epoch 89/100
# 12/12 [==============================] - 0s 821us/step - loss: 0.4891 - accuracy: 0.7662
# Epoch 90/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4886 - accuracy: 0.7662
# Epoch 91/100
# 12/12 [==============================] - 0s 915us/step - loss: 0.4873 - accuracy: 0.7690
# Epoch 92/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4887 - accuracy: 0.7662
# Epoch 93/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4881 - accuracy: 0.7746
# Epoch 94/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4868 - accuracy: 0.7690
# Epoch 95/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4858 - accuracy: 0.7690
# Epoch 96/100
# 12/12 [==============================] - 0s 971us/step - loss: 0.4852 - accuracy: 0.7690
# Epoch 97/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4846 - accuracy: 0.7690
# Epoch 98/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4842 - accuracy: 0.7662
# Epoch 99/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4835 - accuracy: 0.7662
# Epoch 100/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4832 - accuracy: 0.7690
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9306 - accuracy: 0.6371
# Epoch 2/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7622 - accuracy: 0.7608
# Epoch 3/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6488 - accuracy: 0.8898
# Epoch 4/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5759 - accuracy: 0.9113
# Epoch 5/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5223 - accuracy: 0.9194
# Epoch 6/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4848 - accuracy: 0.9247
# Epoch 7/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4535 - accuracy: 0.9301
# Epoch 8/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4291 - accuracy: 0.9355
# Epoch 9/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4079 - accuracy: 0.9382
# Epoch 10/100
# 12/12 [==============================] - 0s 999us/step - loss: 0.3891 - accuracy: 0.9382
# Epoch 11/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3724 - accuracy: 0.9382
# Epoch 12/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3575 - accuracy: 0.9409
# Epoch 13/100
# 12/12 [==============================] - 0s 983us/step - loss: 0.3439 - accuracy: 0.9435
# Epoch 14/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3318 - accuracy: 0.9462
# Epoch 15/100
# 12/12 [==============================] - 0s 976us/step - loss: 0.3203 - accuracy: 0.9570
# Epoch 16/100
# 12/12 [==============================] - 0s 1000us/step - loss: 0.3098 - accuracy: 0.9570
# Epoch 17/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2997 - accuracy: 0.9570
# Epoch 18/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2902 - accuracy: 0.9597
# Epoch 19/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.9624
# Epoch 20/100
# 12/12 [==============================] - 0s 953us/step - loss: 0.2729 - accuracy: 0.9624
# Epoch 21/100
# 12/12 [==============================] - 0s 951us/step - loss: 0.2650 - accuracy: 0.9651
# Epoch 22/100
# 12/12 [==============================] - 0s 832us/step - loss: 0.2571 - accuracy: 0.9677
# Epoch 23/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.9677
# Epoch 24/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2432 - accuracy: 0.9677
# Epoch 25/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2365 - accuracy: 0.9677
# Epoch 26/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2305 - accuracy: 0.9677
# Epoch 27/100
# 12/12 [==============================] - 0s 921us/step - loss: 0.2242 - accuracy: 0.9677
# Epoch 28/100
# 12/12 [==============================] - 0s 917us/step - loss: 0.2186 - accuracy: 0.9677
# Epoch 29/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2128 - accuracy: 0.9677
# Epoch 30/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2079 - accuracy: 0.9677
# Epoch 31/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2026 - accuracy: 0.9677
# Epoch 32/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1977 - accuracy: 0.9677
# Epoch 33/100
# 12/12 [==============================] - 0s 967us/step - loss: 0.1930 - accuracy: 0.9677
# Epoch 34/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1884 - accuracy: 0.9704
# Epoch 35/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1840 - accuracy: 0.9704
# Epoch 36/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1799 - accuracy: 0.9704
# Epoch 37/100
# 12/12 [==============================] - 0s 951us/step - loss: 0.1761 - accuracy: 0.9731
# Epoch 38/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1721 - accuracy: 0.9731
# Epoch 39/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1686 - accuracy: 0.9731
# Epoch 40/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1656 - accuracy: 0.9731
# Epoch 41/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1617 - accuracy: 0.9758
# Epoch 42/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1591 - accuracy: 0.9758
# Epoch 43/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1558 - accuracy: 0.9758
# Epoch 44/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.9731
# Epoch 45/100
# 12/12 [==============================] - 0s 796us/step - loss: 0.1503 - accuracy: 0.9785
# Epoch 46/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1474 - accuracy: 0.9785
# Epoch 47/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1449 - accuracy: 0.9785
# Epoch 48/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1424 - accuracy: 0.9785
# Epoch 49/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1399 - accuracy: 0.9785
# Epoch 50/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1378 - accuracy: 0.9785
# Epoch 51/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1362 - accuracy: 0.9785
# Epoch 52/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1334 - accuracy: 0.9785
# Epoch 53/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1314 - accuracy: 0.9785
# Epoch 54/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1296 - accuracy: 0.9785
# Epoch 55/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1277 - accuracy: 0.9785
# Epoch 56/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1258 - accuracy: 0.9785
# Epoch 57/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1246 - accuracy: 0.9785
# Epoch 58/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1225 - accuracy: 0.9812
# Epoch 59/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1208 - accuracy: 0.9812
# Epoch 60/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1197 - accuracy: 0.9785
# Epoch 61/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1181 - accuracy: 0.9785
# Epoch 62/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1172 - accuracy: 0.9785
# Epoch 63/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1156 - accuracy: 0.9812
# Epoch 64/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1145 - accuracy: 0.9812
# Epoch 65/100
# 12/12 [==============================] - 0s 944us/step - loss: 0.1130 - accuracy: 0.9785
# Epoch 66/100
# 12/12 [==============================] - 0s 948us/step - loss: 0.1115 - accuracy: 0.9812
# Epoch 67/100
# 12/12 [==============================] - 0s 894us/step - loss: 0.1107 - accuracy: 0.9812
# Epoch 68/100
# 12/12 [==============================] - 0s 839us/step - loss: 0.1096 - accuracy: 0.9812
# Epoch 69/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1089 - accuracy: 0.9812
# Epoch 70/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1075 - accuracy: 0.9785
# Epoch 71/100
# 12/12 [==============================] - 0s 854us/step - loss: 0.1068 - accuracy: 0.9785
# Epoch 72/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1058 - accuracy: 0.9812
# Epoch 73/100
# 12/12 [==============================] - 0s 886us/step - loss: 0.1051 - accuracy: 0.9839
# Epoch 74/100
# 12/12 [==============================] - 0s 970us/step - loss: 0.1043 - accuracy: 0.9839
# Epoch 75/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1032 - accuracy: 0.9812
# Epoch 76/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1024 - accuracy: 0.9812
# Epoch 77/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1019 - accuracy: 0.9812
# Epoch 78/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1013 - accuracy: 0.9812
# Epoch 79/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1003 - accuracy: 0.9839
# Epoch 80/100
# 12/12 [==============================] - 0s 940us/step - loss: 0.0998 - accuracy: 0.9839
# Epoch 81/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0990 - accuracy: 0.9812
# Epoch 82/100
# 12/12 [==============================] - 0s 996us/step - loss: 0.0988 - accuracy: 0.9812
# Epoch 83/100
# 12/12 [==============================] - 0s 890us/step - loss: 0.0981 - accuracy: 0.9839
# Epoch 84/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0978 - accuracy: 0.9839
# Epoch 85/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0969 - accuracy: 0.9839
# Epoch 86/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0959 - accuracy: 0.9812
# Epoch 87/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0953 - accuracy: 0.9812
# Epoch 88/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0950 - accuracy: 0.9839
# Epoch 89/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0943 - accuracy: 0.9839
# Epoch 90/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0941 - accuracy: 0.9839
# Epoch 91/100
# 12/12 [==============================] - 0s 951us/step - loss: 0.0935 - accuracy: 0.9839
# Epoch 92/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0927 - accuracy: 0.9839
# Epoch 93/100
# 12/12 [==============================] - 0s 956us/step - loss: 0.0926 - accuracy: 0.9866
# Epoch 94/100
# 12/12 [==============================] - 0s 877us/step - loss: 0.0923 - accuracy: 0.9839
# Epoch 95/100
# 12/12 [==============================] - 0s 929us/step - loss: 0.0916 - accuracy: 0.9839
# Epoch 96/100
# 12/12 [==============================] - 0s 976us/step - loss: 0.0911 - accuracy: 0.9866
# Epoch 97/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0908 - accuracy: 0.9839
# Epoch 98/100
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0901 - accuracy: 0.9866
# Epoch 99/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0900 - accuracy: 0.9866
# Epoch 100/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.9866
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8239 - accuracy: 0.6364
# Epoch 2/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8171 - accuracy: 0.6182
# Epoch 3/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8108 - accuracy: 0.6182
# Epoch 4/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8049 - accuracy: 0.6182
# Epoch 5/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7997 - accuracy: 0.6545
# Epoch 6/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7933 - accuracy: 0.6545
# Epoch 7/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7880 - accuracy: 0.6545
# Epoch 8/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7829 - accuracy: 0.6364
# Epoch 9/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7777 - accuracy: 0.6545
# Epoch 10/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7724 - accuracy: 0.6727
# Epoch 11/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7674 - accuracy: 0.6909
# Epoch 12/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7628 - accuracy: 0.6909
# Epoch 13/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7579 - accuracy: 0.6909
# Epoch 14/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7531 - accuracy: 0.6909
# Epoch 15/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7487 - accuracy: 0.6909
# Epoch 16/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7440 - accuracy: 0.6909
# Epoch 17/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7397 - accuracy: 0.6909
# Epoch 18/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7355 - accuracy: 0.6909
# Epoch 19/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7309 - accuracy: 0.6909
# Epoch 20/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7270 - accuracy: 0.7091
# Epoch 21/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7229 - accuracy: 0.7091
# Epoch 22/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7189 - accuracy: 0.7091
# Epoch 23/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7147 - accuracy: 0.7091
# Epoch 24/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7109 - accuracy: 0.7091
# Epoch 25/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7068 - accuracy: 0.7091
# Epoch 26/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7032 - accuracy: 0.7273
# Epoch 27/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6994 - accuracy: 0.7455
# Epoch 28/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6958 - accuracy: 0.7455
# Epoch 29/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.7455
# Epoch 30/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.6886 - accuracy: 0.7455
# Epoch 31/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6851 - accuracy: 0.7455
# Epoch 32/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6817 - accuracy: 0.7455
# Epoch 33/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6782 - accuracy: 0.7455
# Epoch 34/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6750 - accuracy: 0.7455
# Epoch 35/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6714 - accuracy: 0.7455
# Epoch 36/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6683 - accuracy: 0.7455
# Epoch 37/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6649 - accuracy: 0.7455
# Epoch 38/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6619 - accuracy: 0.7455
# Epoch 39/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6587 - accuracy: 0.7455
# Epoch 40/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6554 - accuracy: 0.7455
# Epoch 41/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6523 - accuracy: 0.7455
# Epoch 42/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6492 - accuracy: 0.7455
# Epoch 43/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6461 - accuracy: 0.7636
# Epoch 44/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6431 - accuracy: 0.7636
# Epoch 45/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6399 - accuracy: 0.7636
# Epoch 46/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6370 - accuracy: 0.7636
# Epoch 47/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6342 - accuracy: 0.7636
# Epoch 48/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6312 - accuracy: 0.7636
# Epoch 49/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6283 - accuracy: 0.7636
# Epoch 50/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6255 - accuracy: 0.7636
# Epoch 51/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6224 - accuracy: 0.7636
# Epoch 52/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6196 - accuracy: 0.7636
# Epoch 53/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6169 - accuracy: 0.7818
# Epoch 54/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6139 - accuracy: 0.7818
# Epoch 55/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6112 - accuracy: 0.7818
# Epoch 56/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6084 - accuracy: 0.7818
# Epoch 57/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6056 - accuracy: 0.7818
# Epoch 58/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6029 - accuracy: 0.7818
# Epoch 59/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6002 - accuracy: 0.7818
# Epoch 60/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5974 - accuracy: 0.7818
# Epoch 61/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5949 - accuracy: 0.7818
# Epoch 62/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5922 - accuracy: 0.8000
# Epoch 63/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5896 - accuracy: 0.8000
# Epoch 64/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5869 - accuracy: 0.8000
# Epoch 65/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.5843 - accuracy: 0.8000
# Epoch 66/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5818 - accuracy: 0.8000
# Epoch 67/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5793 - accuracy: 0.8000
# Epoch 68/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5768 - accuracy: 0.8000
# Epoch 69/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5743 - accuracy: 0.8182
# Epoch 70/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5719 - accuracy: 0.8182
# Epoch 71/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5694 - accuracy: 0.8182
# Epoch 72/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5670 - accuracy: 0.8182
# Epoch 73/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5647 - accuracy: 0.8182
# Epoch 74/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5622 - accuracy: 0.8182
# Epoch 75/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5598 - accuracy: 0.8182
# Epoch 76/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5576 - accuracy: 0.8182
# Epoch 77/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5553 - accuracy: 0.8182
# Epoch 78/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5530 - accuracy: 0.8182
# Epoch 79/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5508 - accuracy: 0.8182
# Epoch 80/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5485 - accuracy: 0.8182
# Epoch 81/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5464 - accuracy: 0.8182
# Epoch 82/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5441 - accuracy: 0.8182
# Epoch 83/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.5419 - accuracy: 0.8182
# Epoch 84/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5399 - accuracy: 0.8182
# Epoch 85/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5377 - accuracy: 0.8364
# Epoch 86/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5355 - accuracy: 0.8364
# Epoch 87/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5334 - accuracy: 0.8364
# Epoch 88/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5315 - accuracy: 0.8364
# Epoch 89/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5294 - accuracy: 0.8364
# Epoch 90/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5273 - accuracy: 0.8364
# Epoch 91/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5253 - accuracy: 0.8364
# Epoch 92/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5233 - accuracy: 0.8364
# Epoch 93/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5215 - accuracy: 0.8364
# Epoch 94/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5195 - accuracy: 0.8364
# Epoch 95/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5176 - accuracy: 0.8364
# Epoch 96/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5156 - accuracy: 0.8364
# Epoch 97/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5138 - accuracy: 0.8364
# Epoch 98/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5119 - accuracy: 0.8364
# Epoch 99/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5102 - accuracy: 0.8364
# Epoch 100/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5083 - accuracy: 0.8364
# 1/1 [==============================] - 0s 53ms/step
# Epoch 1/100
# 13/13 [==============================] - 0s 1ms/step - loss: 1.5046 - accuracy: 0.0827
# Epoch 2/100
# 13/13 [==============================] - 0s 1ms/step - loss: 1.2737 - accuracy: 0.1776
# Epoch 3/100
# 13/13 [==============================] - 0s 1ms/step - loss: 1.0916 - accuracy: 0.3504
# Epoch 4/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.9534 - accuracy: 0.5669
# Epoch 5/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.8387 - accuracy: 0.7616
# Epoch 6/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.7520 - accuracy: 0.8516
# Epoch 7/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.6791 - accuracy: 0.9027
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6216 - accuracy: 0.9246
# Epoch 9/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5759 - accuracy: 0.9343
# Epoch 10/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.5363 - accuracy: 0.9367
# Epoch 11/100
# 13/13 [==============================] - 0s 880us/step - loss: 0.5047 - accuracy: 0.9465
# Epoch 12/100
# 13/13 [==============================] - 0s 804us/step - loss: 0.4782 - accuracy: 0.9465
# Epoch 13/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4561 - accuracy: 0.9489
# Epoch 14/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4373 - accuracy: 0.9489
# Epoch 15/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4213 - accuracy: 0.9489
# Epoch 16/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.4078 - accuracy: 0.9489
# Epoch 17/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3952 - accuracy: 0.9489
# Epoch 18/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3843 - accuracy: 0.9489
# Epoch 19/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3739 - accuracy: 0.9489
# Epoch 20/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3645 - accuracy: 0.9489
# Epoch 21/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3563 - accuracy: 0.9489
# Epoch 22/100
# 13/13 [==============================] - 0s 930us/step - loss: 0.3481 - accuracy: 0.9489
# Epoch 23/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3404 - accuracy: 0.9489
# Epoch 24/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3334 - accuracy: 0.9489
# Epoch 25/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3270 - accuracy: 0.9489
# Epoch 26/100
# 13/13 [==============================] - 0s 993us/step - loss: 0.3207 - accuracy: 0.9489
# Epoch 27/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3147 - accuracy: 0.9489
# Epoch 28/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3090 - accuracy: 0.9489
# Epoch 29/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3038 - accuracy: 0.9489
# Epoch 30/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2984 - accuracy: 0.9489
# Epoch 31/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2938 - accuracy: 0.9489
# Epoch 32/100
# 13/13 [==============================] - 0s 971us/step - loss: 0.2888 - accuracy: 0.9489
# Epoch 33/100
# 13/13 [==============================] - 0s 922us/step - loss: 0.2843 - accuracy: 0.9489
# Epoch 34/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2798 - accuracy: 0.9489
# Epoch 35/100
# 13/13 [==============================] - 0s 899us/step - loss: 0.2757 - accuracy: 0.9489
# Epoch 36/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2717 - accuracy: 0.9489
# Epoch 37/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2678 - accuracy: 0.9489
# Epoch 38/100
# 13/13 [==============================] - 0s 945us/step - loss: 0.2644 - accuracy: 0.9489
# Epoch 39/100
# 13/13 [==============================] - 0s 986us/step - loss: 0.2612 - accuracy: 0.9489
# Epoch 40/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2576 - accuracy: 0.9489
# Epoch 41/100
# 13/13 [==============================] - 0s 970us/step - loss: 0.2543 - accuracy: 0.9489
# Epoch 42/100
# 13/13 [==============================] - 0s 866us/step - loss: 0.2513 - accuracy: 0.9489
# Epoch 43/100
# 13/13 [==============================] - 0s 907us/step - loss: 0.2481 - accuracy: 0.9489
# Epoch 44/100
# 13/13 [==============================] - 0s 999us/step - loss: 0.2455 - accuracy: 0.9489
# Epoch 45/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2427 - accuracy: 0.9489
# Epoch 46/100
# 13/13 [==============================] - 0s 956us/step - loss: 0.2401 - accuracy: 0.9489
# Epoch 47/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2377 - accuracy: 0.9489
# Epoch 48/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2352 - accuracy: 0.9489
# Epoch 49/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2333 - accuracy: 0.9489
# Epoch 50/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2311 - accuracy: 0.9489
# Epoch 51/100
# 13/13 [==============================] - 0s 936us/step - loss: 0.2289 - accuracy: 0.9489
# Epoch 52/100
# 13/13 [==============================] - 0s 991us/step - loss: 0.2267 - accuracy: 0.9489
# Epoch 53/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2246 - accuracy: 0.9489
# Epoch 54/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2227 - accuracy: 0.9489
# Epoch 55/100
# 13/13 [==============================] - 0s 969us/step - loss: 0.2210 - accuracy: 0.9489
# Epoch 56/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2193 - accuracy: 0.9489
# Epoch 57/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2174 - accuracy: 0.9489
# Epoch 58/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2158 - accuracy: 0.9489
# Epoch 59/100
# 13/13 [==============================] - 0s 922us/step - loss: 0.2145 - accuracy: 0.9489
# Epoch 60/100
# 13/13 [==============================] - 0s 990us/step - loss: 0.2126 - accuracy: 0.9489
# Epoch 61/100
# 13/13 [==============================] - 0s 938us/step - loss: 0.2113 - accuracy: 0.9489
# Epoch 62/100
# 13/13 [==============================] - 0s 900us/step - loss: 0.2104 - accuracy: 0.9489
# Epoch 63/100
# 13/13 [==============================] - 0s 930us/step - loss: 0.2085 - accuracy: 0.9489
# Epoch 64/100
# 13/13 [==============================] - 0s 903us/step - loss: 0.2073 - accuracy: 0.9489
# Epoch 65/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2060 - accuracy: 0.9489
# Epoch 66/100
# 13/13 [==============================] - 0s 965us/step - loss: 0.2047 - accuracy: 0.9513
# Epoch 67/100
# 13/13 [==============================] - 0s 948us/step - loss: 0.2037 - accuracy: 0.9513
# Epoch 68/100
# 13/13 [==============================] - 0s 959us/step - loss: 0.2026 - accuracy: 0.9513
# Epoch 69/100
# 13/13 [==============================] - 0s 916us/step - loss: 0.2015 - accuracy: 0.9489
# Epoch 70/100
# 13/13 [==============================] - 0s 902us/step - loss: 0.2005 - accuracy: 0.9489
# Epoch 71/100
# 13/13 [==============================] - 0s 943us/step - loss: 0.1989 - accuracy: 0.9513
# Epoch 72/100
# 13/13 [==============================] - 0s 898us/step - loss: 0.1980 - accuracy: 0.9489
# Epoch 73/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1971 - accuracy: 0.9489
# Epoch 74/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1958 - accuracy: 0.9513
# Epoch 75/100
# 13/13 [==============================] - 0s 964us/step - loss: 0.1952 - accuracy: 0.9513
# Epoch 76/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1948 - accuracy: 0.9513
# Epoch 77/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1931 - accuracy: 0.9538
# Epoch 78/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1927 - accuracy: 0.9513
# Epoch 79/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1916 - accuracy: 0.9513
# Epoch 80/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1907 - accuracy: 0.9513
# Epoch 81/100
# 13/13 [==============================] - 0s 969us/step - loss: 0.1901 - accuracy: 0.9538
# Epoch 82/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1890 - accuracy: 0.9513
# Epoch 83/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1883 - accuracy: 0.9513
# Epoch 84/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1877 - accuracy: 0.9513
# Epoch 85/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1868 - accuracy: 0.9538
# Epoch 86/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1863 - accuracy: 0.9489
# Epoch 87/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1852 - accuracy: 0.9538
# Epoch 88/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1847 - accuracy: 0.9538
# Epoch 89/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1839 - accuracy: 0.9538
# Epoch 90/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1832 - accuracy: 0.9513
# Epoch 91/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1825 - accuracy: 0.9513
# Epoch 92/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1821 - accuracy: 0.9538
# Epoch 93/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1813 - accuracy: 0.9562
# Epoch 94/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1812 - accuracy: 0.9538
# Epoch 95/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1805 - accuracy: 0.9538
# Epoch 96/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1797 - accuracy: 0.9562
# Epoch 97/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1796 - accuracy: 0.9562
# Epoch 98/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1787 - accuracy: 0.9538
# Epoch 99/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1784 - accuracy: 0.9562
# Epoch 100/100
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1778 - accuracy: 0.9562
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.9336 - accuracy: 0.5174
# Epoch 2/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.8597 - accuracy: 0.6178
# Epoch 3/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.7968 - accuracy: 0.7104
# Epoch 4/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7434 - accuracy: 0.7799
# Epoch 5/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6985 - accuracy: 0.8456
# Epoch 6/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6584 - accuracy: 0.8687
# Epoch 7/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6242 - accuracy: 0.8919
# Epoch 8/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5931 - accuracy: 0.9035
# Epoch 9/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5662 - accuracy: 0.9189
# Epoch 10/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5427 - accuracy: 0.9344
# Epoch 11/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.5218 - accuracy: 0.9305
# Epoch 12/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.5032 - accuracy: 0.9344
# Epoch 13/100
# 9/9 [==============================] - 0s 903us/step - loss: 0.4861 - accuracy: 0.9344
# Epoch 14/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.4705 - accuracy: 0.9344
# Epoch 15/100
# 9/9 [==============================] - 0s 963us/step - loss: 0.4567 - accuracy: 0.9344
# Epoch 16/100
# 9/9 [==============================] - 0s 835us/step - loss: 0.4437 - accuracy: 0.9344
# Epoch 17/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.4322 - accuracy: 0.9344
# Epoch 18/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.4211 - accuracy: 0.9344
# Epoch 19/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.4113 - accuracy: 0.9344
# Epoch 20/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.4015 - accuracy: 0.9344
# Epoch 21/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.3928 - accuracy: 0.9344
# Epoch 22/100
# 9/9 [==============================] - 0s 818us/step - loss: 0.3844 - accuracy: 0.9344
# Epoch 23/100
# 9/9 [==============================] - 0s 750us/step - loss: 0.3767 - accuracy: 0.9344
# Epoch 24/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.3691 - accuracy: 0.9344
# Epoch 25/100
# 9/9 [==============================] - 0s 867us/step - loss: 0.3618 - accuracy: 0.9344
# Epoch 26/100
# 9/9 [==============================] - 0s 1000us/step - loss: 0.3549 - accuracy: 0.9344
# Epoch 27/100
# 9/9 [==============================] - 0s 950us/step - loss: 0.3481 - accuracy: 0.9344
# Epoch 28/100
# 9/9 [==============================] - 0s 984us/step - loss: 0.3413 - accuracy: 0.9344
# Epoch 29/100
# 9/9 [==============================] - 0s 894us/step - loss: 0.3354 - accuracy: 0.9344
# Epoch 30/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.3295 - accuracy: 0.9344
# Epoch 31/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.3239 - accuracy: 0.9344
# Epoch 32/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.3185 - accuracy: 0.9344
# Epoch 33/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.3132 - accuracy: 0.9344
# Epoch 34/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.3080 - accuracy: 0.9344
# Epoch 35/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.3030 - accuracy: 0.9344
# Epoch 36/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2980 - accuracy: 0.9344
# Epoch 37/100
# 9/9 [==============================] - 0s 935us/step - loss: 0.2935 - accuracy: 0.9344
# Epoch 38/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2891 - accuracy: 0.9344
# Epoch 39/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2858 - accuracy: 0.9344
# Epoch 40/100
# 9/9 [==============================] - 0s 984us/step - loss: 0.2815 - accuracy: 0.9344
# Epoch 41/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2778 - accuracy: 0.9344
# Epoch 42/100
# 9/9 [==============================] - 0s 939us/step - loss: 0.2739 - accuracy: 0.9344
# Epoch 43/100
# 9/9 [==============================] - 0s 926us/step - loss: 0.2700 - accuracy: 0.9344
# Epoch 44/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2664 - accuracy: 0.9344
# Epoch 45/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2627 - accuracy: 0.9344
# Epoch 46/100
# 9/9 [==============================] - 0s 953us/step - loss: 0.2593 - accuracy: 0.9344
# Epoch 47/100
# 9/9 [==============================] - 0s 992us/step - loss: 0.2562 - accuracy: 0.9344
# Epoch 48/100
# 9/9 [==============================] - 0s 967us/step - loss: 0.2530 - accuracy: 0.9344
# Epoch 49/100
# 9/9 [==============================] - 0s 993us/step - loss: 0.2497 - accuracy: 0.9344
# Epoch 50/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2467 - accuracy: 0.9344
# Epoch 51/100
# 9/9 [==============================] - 0s 955us/step - loss: 0.2437 - accuracy: 0.9344
# Epoch 52/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2407 - accuracy: 0.9344
# Epoch 53/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2379 - accuracy: 0.9344
# Epoch 54/100
# 9/9 [==============================] - 0s 886us/step - loss: 0.2350 - accuracy: 0.9344
# Epoch 55/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2324 - accuracy: 0.9344
# Epoch 56/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2297 - accuracy: 0.9344
# Epoch 57/100
# 9/9 [==============================] - 0s 848us/step - loss: 0.2272 - accuracy: 0.9344
# Epoch 58/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2247 - accuracy: 0.9382
# Epoch 59/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2224 - accuracy: 0.9382
# Epoch 60/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2198 - accuracy: 0.9382
# Epoch 61/100
# 9/9 [==============================] - 0s 994us/step - loss: 0.2176 - accuracy: 0.9382
# Epoch 62/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2155 - accuracy: 0.9382
# Epoch 63/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2132 - accuracy: 0.9382
# Epoch 64/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2114 - accuracy: 0.9382
# Epoch 65/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2090 - accuracy: 0.9382
# Epoch 66/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2069 - accuracy: 0.9421
# Epoch 67/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2050 - accuracy: 0.9421
# Epoch 68/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2037 - accuracy: 0.9421
# Epoch 69/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2018 - accuracy: 0.9421
# Epoch 70/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2000 - accuracy: 0.9421
# Epoch 71/100
# 9/9 [==============================] - 0s 943us/step - loss: 0.1982 - accuracy: 0.9421
# Epoch 72/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.9421
# Epoch 73/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1946 - accuracy: 0.9421
# Epoch 74/100
# 9/9 [==============================] - 0s 997us/step - loss: 0.1928 - accuracy: 0.9421
# Epoch 75/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1910 - accuracy: 0.9421
# Epoch 76/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1892 - accuracy: 0.9421
# Epoch 77/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1876 - accuracy: 0.9421
# Epoch 78/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1859 - accuracy: 0.9421
# Epoch 79/100
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 0.9421
# Epoch 80/100
# ...
# Epoch 42/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2880 - accuracy: 0.9524
# Epoch 43/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2843 - accuracy: 0.9524
# Epoch 44/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2804 - accuracy: 0.9577
# Epoch 45/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2768 - accuracy: 0.9577
# Epoch 46/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2735 - accuracy: 0.9577
# Epoch 47/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2702 - accuracy: 0.9577
# Epoch 48/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2670 - accuracy: 0.9577
# Epoch 49/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2639 - accuracy: 0.9577
# Epoch 50/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2609 - accuracy: 0.9577
# Epoch 51/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2579 - accuracy: 0.9577
# Epoch 52/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2552 - accuracy: 0.9577
# Epoch 53/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.9577
# Epoch 54/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2497 - accuracy: 0.9577
# Epoch 55/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2471 - accuracy: 0.9577
# Epoch 56/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2446 - accuracy: 0.9577
# Epoch 57/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.9577
# Epoch 58/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.9577
# Epoch 59/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2373 - accuracy: 0.9577
# Epoch 60/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2350 - accuracy: 0.9577
# Epoch 61/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2328 - accuracy: 0.9577
# Epoch 62/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2307 - accuracy: 0.9577
# Epoch 63/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2285 - accuracy: 0.9577
# Epoch 64/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2265 - accuracy: 0.9577
# Epoch 65/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2244 - accuracy: 0.9577
# Epoch 66/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2226 - accuracy: 0.9577
# Epoch 67/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2207 - accuracy: 0.9577
# Epoch 68/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2189 - accuracy: 0.9630
# Epoch 69/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2171 - accuracy: 0.9630
# Epoch 70/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2154 - accuracy: 0.9630
# Epoch 71/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2137 - accuracy: 0.9630
# Epoch 72/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2121 - accuracy: 0.9630
# Epoch 73/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2106 - accuracy: 0.9630
# Epoch 74/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2090 - accuracy: 0.9630
# Epoch 75/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2076 - accuracy: 0.9630
# Epoch 76/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2061 - accuracy: 0.9630
# Epoch 77/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2047 - accuracy: 0.9630
# Epoch 78/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2033 - accuracy: 0.9630
# Epoch 79/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2019 - accuracy: 0.9630
# Epoch 80/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.2005 - accuracy: 0.9630
# Epoch 81/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1992 - accuracy: 0.9630
# Epoch 82/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1979 - accuracy: 0.9630
# Epoch 83/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1967 - accuracy: 0.9630
# Epoch 84/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1954 - accuracy: 0.9630
# Epoch 85/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1943 - accuracy: 0.9630
# Epoch 86/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1931 - accuracy: 0.9630
# Epoch 87/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1919 - accuracy: 0.9683
# Epoch 88/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1909 - accuracy: 0.9683
# Epoch 89/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1898 - accuracy: 0.9683
# Epoch 90/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1887 - accuracy: 0.9683
# Epoch 91/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1876 - accuracy: 0.9683
# Epoch 92/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1866 - accuracy: 0.9683
# Epoch 93/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1855 - accuracy: 0.9683
# Epoch 94/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1845 - accuracy: 0.9683
# Epoch 95/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1835 - accuracy: 0.9683
# Epoch 96/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1825 - accuracy: 0.9683
# Epoch 97/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1816 - accuracy: 0.9683
# Epoch 98/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1807 - accuracy: 0.9683
# Epoch 99/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1798 - accuracy: 0.9683
# Epoch 100/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1790 - accuracy: 0.9683
# 2/2 [==============================] - 0s 4ms/step
# Epoch 1/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.2115 - accuracy: 0.4674
# Epoch 2/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.8920 - accuracy: 0.7478
# Epoch 3/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.7583 - accuracy: 0.8196
# Epoch 4/100
# 15/15 [==============================] - 0s 936us/step - loss: 0.6822 - accuracy: 0.8609
# Epoch 5/100
# 15/15 [==============================] - 0s 961us/step - loss: 0.6322 - accuracy: 0.8870
# Epoch 6/100
# 15/15 [==============================] - 0s 864us/step - loss: 0.5967 - accuracy: 0.8891
# Epoch 7/100
# 15/15 [==============================] - 0s 845us/step - loss: 0.5670 - accuracy: 0.8957
# Epoch 8/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5427 - accuracy: 0.8978
# Epoch 9/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5200 - accuracy: 0.9043
# Epoch 10/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5004 - accuracy: 0.9022
# Epoch 11/100
# 15/15 [==============================] - 0s 992us/step - loss: 0.4824 - accuracy: 0.9065
# Epoch 12/100
# 15/15 [==============================] - 0s 981us/step - loss: 0.4650 - accuracy: 0.9130
# Epoch 13/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4493 - accuracy: 0.9130
# Epoch 14/100
# 15/15 [==============================] - 0s 992us/step - loss: 0.4341 - accuracy: 0.9152
# Epoch 15/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4210 - accuracy: 0.9152
# Epoch 16/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4078 - accuracy: 0.9152
# Epoch 17/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3957 - accuracy: 0.9217
# Epoch 18/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3840 - accuracy: 0.9196
# Epoch 19/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3736 - accuracy: 0.9174
# Epoch 20/100
# 15/15 [==============================] - 0s 972us/step - loss: 0.3627 - accuracy: 0.9239
# Epoch 21/100
# 15/15 [==============================] - 0s 997us/step - loss: 0.3528 - accuracy: 0.9239
# Epoch 22/100
# 15/15 [==============================] - 0s 986us/step - loss: 0.3438 - accuracy: 0.9304
# Epoch 23/100
# 15/15 [==============================] - 0s 951us/step - loss: 0.3383 - accuracy: 0.9239
# Epoch 24/100
# 15/15 [==============================] - 0s 815us/step - loss: 0.3270 - accuracy: 0.9261
# Epoch 25/100
# 15/15 [==============================] - 0s 862us/step - loss: 0.3197 - accuracy: 0.9283
# Epoch 26/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3122 - accuracy: 0.9304
# Epoch 27/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3049 - accuracy: 0.9239
# Epoch 28/100
# 15/15 [==============================] - 0s 978us/step - loss: 0.2990 - accuracy: 0.9261
# Epoch 29/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2926 - accuracy: 0.9261
# Epoch 30/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2867 - accuracy: 0.9304
# Epoch 31/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2806 - accuracy: 0.9283
# Epoch 32/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2761 - accuracy: 0.9261
# Epoch 33/100
# 15/15 [==============================] - 0s 966us/step - loss: 0.2706 - accuracy: 0.9261
# Epoch 34/100
# 15/15 [==============================] - 0s 990us/step - loss: 0.2658 - accuracy: 0.9283
# Epoch 35/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2621 - accuracy: 0.9326
# Epoch 36/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2563 - accuracy: 0.9304
# Epoch 37/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2527 - accuracy: 0.9261
# Epoch 38/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.9304
# Epoch 39/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2451 - accuracy: 0.9304
# Epoch 40/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2406 - accuracy: 0.9304
# Epoch 41/100
# 15/15 [==============================] - 0s 999us/step - loss: 0.2373 - accuracy: 0.9326
# Epoch 42/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2349 - accuracy: 0.9326
# Epoch 43/100
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2323 - accuracy: 0.9326
# Epoch 44/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2297 - accuracy: 0.9326
# Epoch 45/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2260 - accuracy: 0.9348
# Epoch 46/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2232 - accuracy: 0.9261
# Epoch 47/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2208 - accuracy: 0.9326
# Epoch 48/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2178 - accuracy: 0.9326
# Epoch 49/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2152 - accuracy: 0.9348
# Epoch 50/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2144 - accuracy: 0.9348
# Epoch 51/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2107 - accuracy: 0.9348
# Epoch 52/100
# 15/15 [==============================] - 0s 934us/step - loss: 0.2094 - accuracy: 0.9326
# Epoch 53/100
# 15/15 [==============================] - 0s 929us/step - loss: 0.2062 - accuracy: 0.9391
# Epoch 54/100
# 15/15 [==============================] - 0s 964us/step - loss: 0.2049 - accuracy: 0.9370
# Epoch 55/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2024 - accuracy: 0.9326
# Epoch 56/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2012 - accuracy: 0.9370
# Epoch 57/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1986 - accuracy: 0.9370
# Epoch 58/100
# 15/15 [==============================] - 0s 982us/step - loss: 0.1969 - accuracy: 0.9391
# Epoch 59/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1955 - accuracy: 0.9348
# Epoch 60/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1948 - accuracy: 0.9348
# Epoch 61/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1930 - accuracy: 0.9370
# Epoch 62/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1919 - accuracy: 0.9391
# Epoch 63/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1896 - accuracy: 0.9370
# Epoch 64/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1891 - accuracy: 0.9391
# Epoch 65/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1872 - accuracy: 0.9370
# Epoch 66/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1860 - accuracy: 0.9370
# Epoch 67/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1853 - accuracy: 0.9348
# Epoch 68/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1862 - accuracy: 0.9348
# Epoch 69/100
# 15/15 [==============================] - 0s 941us/step - loss: 0.1821 - accuracy: 0.9391
# Epoch 70/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1826 - accuracy: 0.9370
# Epoch 71/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1797 - accuracy: 0.9370
# Epoch 72/100
# 15/15 [==============================] - 0s 973us/step - loss: 0.1786 - accuracy: 0.9370
# Epoch 73/100
# 15/15 [==============================] - 0s 991us/step - loss: 0.1785 - accuracy: 0.9326
# Epoch 74/100
# 15/15 [==============================] - 0s 977us/step - loss: 0.1788 - accuracy: 0.9413
# Epoch 75/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1757 - accuracy: 0.9391
# Epoch 76/100
# 15/15 [==============================] - 0s 980us/step - loss: 0.1764 - accuracy: 0.9457
# Epoch 77/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1736 - accuracy: 0.9391
# Epoch 78/100
# 15/15 [==============================] - 0s 905us/step - loss: 0.1742 - accuracy: 0.9391
# Epoch 79/100
# 15/15 [==============================] - 0s 911us/step - loss: 0.1733 - accuracy: 0.9413
# Epoch 80/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1728 - accuracy: 0.9391
# Epoch 81/100
# 15/15 [==============================] - 0s 974us/step - loss: 0.1717 - accuracy: 0.9391
# Epoch 82/100
# 15/15 [==============================] - 0s 954us/step - loss: 0.1702 - accuracy: 0.9435
# Epoch 83/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1711 - accuracy: 0.9370
# Epoch 84/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1706 - accuracy: 0.9457
# Epoch 85/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1695 - accuracy: 0.9457
# Epoch 86/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1733 - accuracy: 0.9370
# Epoch 87/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1697 - accuracy: 0.9478
# Epoch 88/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1685 - accuracy: 0.9457
# Epoch 89/100
# 15/15 [==============================] - 0s 908us/step - loss: 0.1666 - accuracy: 0.9478
# Epoch 90/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1658 - accuracy: 0.9435
# Epoch 91/100
# 15/15 [==============================] - 0s 986us/step - loss: 0.1654 - accuracy: 0.9435
# Epoch 92/100
# 15/15 [==============================] - 0s 999us/step - loss: 0.1655 - accuracy: 0.9435
# Epoch 93/100
# 15/15 [==============================] - 0s 926us/step - loss: 0.1650 - accuracy: 0.9457
# Epoch 94/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1639 - accuracy: 0.9435
# Epoch 95/100
# 15/15 [==============================] - 0s 974us/step - loss: 0.1635 - accuracy: 0.9413
# Epoch 96/100
# 15/15 [==============================] - 0s 960us/step - loss: 0.1637 - accuracy: 0.9435
# Epoch 97/100
# 15/15 [==============================] - 0s 922us/step - loss: 0.1619 - accuracy: 0.9435
# Epoch 98/100
# 15/15 [==============================] - 0s 897us/step - loss: 0.1623 - accuracy: 0.9457
# Epoch 99/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1625 - accuracy: 0.9435
# Epoch 100/100
# 15/15 [==============================] - 0s 936us/step - loss: 0.1633 - accuracy: 0.9435
# 4/4 [==============================] - 0s 1ms/step
# 0.8395031344242876

# %% [markdown]
# ## Inference Model

# %%
y_predicts=[]
for i in range(len(dataset_names)):
    # print(X_tests[i])
#     print(X_tests[i].shape)
#     print(models[i].layers[0].input_shape)


    y_predict_proba=models[i].predict(X_tests[i]).ravel()
    df = pd.DataFrame(y_predict_proba, columns=['y_predict_proba'])
    y_predicts.append(df)
# Out:
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 976us/step
# 7/7 [==============================] - 0s 994us/step
# 7/7 [==============================] - 0s 898us/step
# 8/8 [==============================] - 0s 985us/step
# 4/4 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 0s 993us/step
# 2/2 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 755us/step
# 13/13 [==============================] - 0s 661us/step
# 3/3 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 920us/step
# 5/5 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 847us/step
# 7/7 [==============================] - 0s 980us/step
# 12/12 [==============================] - 0s 654us/step
# 2/2 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 739us/step
# 5/5 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1000us/step
# 8/8 [==============================] - 0s 1ms/step
# 13/13 [==============================] - 0s 801us/step
# 10/10 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 13/13 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Save result

# %%
for idx,dataset_name in enumerate(dataset_names):
    df=y_predicts[idx]
    df.to_csv(f'./Competition_data/{dataset_name}/y_predict.csv', index=False,header=True)

# %%
# from sklearn.metrics import roc_auc_score

# test_aucs = []
# for i in range(len(dataset_names)):
#     # 使用模型進行預測，獲得類別 1 的預測機率
#     y_predict_proba = models[i].predict_proba(X_tests[i])[:, 1]
    
#     # 計算 AUC 分數
#     auc = roc_auc_score(y_tests[i], y_predict_proba)
#     print(f'AUC of dataset {i:2}: \t{auc}')
    
#     test_aucs.append(auc)

# # 平均 AUC
# avg_test_auc = sum(test_aucs) / len(test_aucs)
# print("\nAverage Test AUC:", avg_test_auc)
